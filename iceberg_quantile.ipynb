# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from scipy.stats import skew, kurtosis
import yfinance as yf

# %%
results_ib_2min = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/results_portfolio_iceberg_log_ret_ex_momum_2min.csv")
pnl_ib_2min = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/pnl_portfolio_iceberg_log_ret_ex_momum_2min.csv")
counts_ib_2min = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/counts_portfolio_iceberg_log_ret_ex_momum_2min.csv")

results_ib_30s = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/results_portfolio_iceberg_log_ret_ex_momum_30S.csv")
pnl_ib_30s = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/pnl_portfolio_iceberg_log_ret_ex_momum_30S.csv")
counts_ib_30s = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/counts_portfolio_iceberg_log_ret_ex_momum_30S.csv")

results_ib_10min = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/results_portfolio_iceberg_log_ret_ex_momum_10min.csv")
pnl_ib_10min = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/pnl_portfolio_iceberg_log_ret_ex_momum_10min.csv")
counts_ib_10min = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/counts_portfolio_iceberg_log_ret_ex_momum_10min.csv")

results_ib_2min_30 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/results_portfolio_iceberg_log_ret_ex_momum_{'0.3'}_2min.csv")
pnl_ib_2min_30 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/pnl_portfolio_iceberg_log_ret_ex_momum_{'0.3'}_2min.csv")
counts_ib_2min_30 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/counts_portfolio_iceberg_log_ret_ex_momum_{'0.3'}_2min.csv")

results_ib_30s_30 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/results_portfolio_iceberg_log_ret_ex_momum_{'0.3'}_30S.csv")
pnl_ib_30s_30 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/pnl_portfolio_iceberg_log_ret_ex_momum_{'0.3'}_30S.csv")
counts_ib_30s_30 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/counts_portfolio_iceberg_log_ret_ex_momum_{'0.3'}_30S.csv")

results_ib_10min_30 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/results_portfolio_iceberg_log_ret_ex_momum_{'0.3'}_10min.csv")
pnl_ib_10min_30 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/pnl_portfolio_iceberg_log_ret_ex_momum_{'0.3'}_10min.csv")
counts_ib_10min_30 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/counts_portfolio_iceberg_log_ret_ex_momum_{'0.3'}_10min.csv")

results_ib_2min_40 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/results_portfolio_iceberg_log_ret_ex_momum_{'0.4'}_2min.csv")
pnl_ib_2min_40 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/pnl_portfolio_iceberg_log_ret_ex_momum_{'0.4'}_2min.csv")
counts_ib_2min_40 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/counts_portfolio_iceberg_log_ret_ex_momum_{'0.4'}_2min.csv")

results_ib_30s_40 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/results_portfolio_iceberg_log_ret_ex_momum_{'0.4'}_30S.csv")
pnl_ib_30s_40 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/pnl_portfolio_iceberg_log_ret_ex_momum_{'0.4'}_30S.csv")
counts_ib_30s_40 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/counts_portfolio_iceberg_log_ret_ex_momum_{'0.4'}_30S.csv")

results_ib_10min_40 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/results_portfolio_iceberg_log_ret_ex_momum_{'0.4'}_10min.csv")
pnl_ib_10min_40 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/pnl_portfolio_iceberg_log_ret_ex_momum_{'0.4'}_10min.csv")
counts_ib_10min_40 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/counts_portfolio_iceberg_log_ret_ex_momum_{'0.4'}_10min.csv")


results_ib_30s_10 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/results_portfolio_iceberg_log_ret_ex_momum_{'0.1'}_30S.csv")
pnl_ib_30s_10 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/pnl_portfolio_iceberg_log_ret_ex_momum_{'0.1'}_30S.csv")
counts_ib_30s_10 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/counts_portfolio_iceberg_log_ret_ex_momum_{'0.1'}_30S.csv")

results_ib_2min_10 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/results_portfolio_iceberg_log_ret_ex_momum_{'0.1'}_2min.csv")
pnl_ib_2min_10 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/pnl_portfolio_iceberg_log_ret_ex_momum_{'0.1'}_2min.csv")
counts_ib_2min_10 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/counts_portfolio_iceberg_log_ret_ex_momum_{'0.1'}_2min.csv")

results_ib_10min_10 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/results_portfolio_iceberg_log_ret_ex_momum_{'0.1'}_10min.csv")
pnl_ib_10min_10 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/pnl_portfolio_iceberg_log_ret_ex_momum_{'0.1'}_10min.csv")
counts_ib_10min_10 = pd.read_csv(f"/nfs/home/jingt/dissertation-iceberg/data/output_results/strategy_results/counts_portfolio_iceberg_log_ret_ex_momum_{'0.1'}_10min.csv")


results_ib_2min.set_index("date", inplace=True)
results_ib_30s.set_index("date", inplace=True)
results_ib_10min.set_index("date", inplace=True)


results_ib_2min_30.set_index("date", inplace=True)
results_ib_30s_30.set_index("date", inplace=True)
results_ib_10min_30.set_index("date", inplace=True)


results_ib_2min_40.set_index("date", inplace=True)
results_ib_30s_40.set_index("date", inplace=True)
results_ib_10min_40.set_index("date", inplace=True)


results_ib_2min_10.set_index("date", inplace=True)
results_ib_30s_10.set_index("date", inplace=True)
results_ib_10min_10.set_index("date", inplace=True)

# %%
results_lst = [results_ib_30s_10, results_ib_2min_10, results_ib_10min_10,
               results_ib_30s, results_ib_2min, results_ib_10min,
               results_ib_30s_30, results_ib_2min_30, results_ib_10min_30,
               results_ib_30s_40, results_ib_2min_40, results_ib_10min_40]
pnl_lst = [pnl_ib_30s_10, pnl_ib_2min_10, pnl_ib_10min_10,
           pnl_ib_30s, pnl_ib_2min, pnl_ib_10min,
           pnl_ib_30s_30, pnl_ib_2min_30, pnl_ib_10min_30,
           pnl_ib_30s_40, pnl_ib_2min_40, pnl_ib_10min_40]
counts_lst = [counts_ib_30s_10, counts_ib_2min_10, counts_ib_10min_10,
              counts_ib_30s, counts_ib_2min, counts_ib_10min,
              counts_ib_30s_30, counts_ib_2min_30, counts_ib_10min_30,
              counts_ib_30s_40, counts_ib_2min_40, counts_ib_10min_40]



label_lst = ['VHI 30s (10%)', 'VHI 2min (10%)', 'VHI 10min (10%)',
             'VHI 30s (20%)', 'VHI 2min (20%)', 'VHI 10min (20%)',
             'VHI 30s (30%)', 'VHI 2min (30%)', 'VHI 10min (30%)',
             'VHI 30s (40%)', 'VHI 2min (40%)', 'VHI 10min (40%)']

# %%
# Plot cumulative PnL for each ticker
plt.figure(figsize=(14, 8))


for results, label in zip(results_lst, label_lst):
    cumulative_pnl = results['PnL'].cumsum().to_frame()
    plt.plot(cumulative_pnl.index, cumulative_pnl['PnL'], label=label)


plt.axhline(y=0, color='black', linestyle='--', linewidth=1)

# Add title and labels
plt.title('Cumulative PnL (log returns) for Portfolio Strategies', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Cumulative PnL', fontsize=14)

# Rotate x-axis labels and reduce ticks
plt.xticks(ticks=range(0, len(cumulative_pnl.index), 5), labels=cumulative_pnl.index[::5], rotation=45)


# Add legend
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=12)

# Adjust layout to fit legend
plt.tight_layout()

# Show plot
plt.show()

# %%
def sharpe_test(returns, count_df):
    # Calculate the Sharpe ratio
    sharpe_ratio = np.mean(returns) / np.std(returns, ddof=1)
    
    # Number of observations
    T = len(returns)
    
    # Calculate skewness and kurtosis
    g3 = skew(returns)
    g4 = kurtosis(returns, fisher=False)  # fisher=False to match R's kurtosis (which includes the 3)
    
    # Calculate the modified Sharpe ratio statistic
    denominator = np.sqrt((1 - g3 * sharpe_ratio + (g4 - 1) * (sharpe_ratio ** 2) / 4) / (T - 1))
    modified_sharpe_stat = sharpe_ratio / denominator
    # Calculate the two-tailed p-value
    p_value = 2 * min(norm.cdf(modified_sharpe_stat), 1 - norm.cdf(modified_sharpe_stat))
    
    annual_sharpe = sharpe_ratio * np.sqrt(252)
    
    PPT = np.sum(returns) / (count_df[['top_counts', 'bottom_counts']].sum(axis=1).sum()) * 10000
    
    return annual_sharpe, PPT, modified_sharpe_stat, p_value

# %%
sharpe_lst = []
SR_test_lst = []
pval_lst = []
ppt_lst = []


for result, counts in zip(results_lst, counts_lst):
    annual_sharpe, PPT, sharpe_stat, p_val = sharpe_test(result['PnL'], counts)
    sharpe_lst.append(annual_sharpe)
    ppt_lst.append(PPT)
    SR_test_lst.append(sharpe_stat)
    pval_lst.append(p_val)

sharpe_df = pd.DataFrame({'Portfolio': label_lst, 'Annual SR': sharpe_lst, 'PPT': ppt_lst,
                          'SR_statistic': SR_test_lst, 'pval': pval_lst})
sharpe_df.sort_values(by='Annual SR', ascending=False, inplace=True)
sharpe_df
# Out:
#           Portfolio  Annual SR       PPT  SR_statistic          pval
# 9     VHI 30s (40%)  28.615376  0.145421     17.099575  0.000000e+00
# 6     VHI 30s (30%)  27.543839  0.166194     16.233451  0.000000e+00
# 3     VHI 30s (20%)  26.291671  0.211573     15.997531  0.000000e+00
# 0     VHI 30s (10%)  23.255808  0.269634     10.096478  0.000000e+00
# 10   VHI 2min (40%)   6.260565  0.088192      6.109273  1.000859e-09
# 7    VHI 2min (30%)   5.772292  0.094796      5.770538  7.901877e-09
# 4    VHI 2min (20%)   5.470500  0.118350      5.596736  2.184255e-08
# 1    VHI 2min (10%)   5.398337  0.193856      5.483953  4.159259e-08
# 2   VHI 10min (10%)   2.411412  0.283777      2.369105  1.783117e-02
# 8   VHI 10min (30%)   2.258887  0.153590      2.237172  2.527512e-02
# 11  VHI 10min (40%)   2.238056  0.135248      2.230978  2.568259e-02
# 5   VHI 10min (20%)   1.561937  0.129253      1.563185  1.180090e-01
