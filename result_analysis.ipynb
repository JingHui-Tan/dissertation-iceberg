# %%
import pandas as pd
import matplotlib.pyplot as plt
from chunk_pipeline import order_imbalance_calc
import warnings

from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
ticker = 'AES'
order_type = 'combined'
delta_lst = ['15S', '30S', '1min', '2min', '5min', '10min']

# %%
folder_path = "/nfs/home/jingt/dissertation-iceberg/data/output_results"
model_path = "/nfs/home/jingt/dissertation-iceberg/data/output_folder"
archive_train_path = f"/nfs/home/jingt/dissertation-iceberg/data/training_data/_data_dwn_32_210_hidden_liquidity_{ticker}_2012-01-01_2012-12-31_1.7z"
arhive_test_path = f"/nfs/data/lobster_data/lobster_raw/2017-19/_data_dwn_32_302__{ticker}_2019-01-01_2019-12-31_10.7z"
model_name = f"xgboost_{ticker}.json"

# %%
df_dict = order_imbalance_calc(arhive_test_path, delta_lst=delta_lst, model=None,
                                        model_path=model_path, model_name=model_name, 
                                        order_type=order_type)
# Out:
# Processed files: AES_2019-01-02_34200000_57600000_orderbook_10.csv AES_2019-01-02_34200000_57600000_message_10.csv
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:260: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df.drop(columns=['event_type', 'order_ID', 'price', 'direction', 'midprice'], inplace=True)
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[numerical_columns] = scaler.fit_transform(features_df[numerical_columns])
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[col] = features_df[col].astype('category')
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# Processed files: AES_2019-01-03_34200000_57600000_orderbook_10.csv AES_2019-01-03_34200000_57600000_message_10.csv
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:260: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df.drop(columns=['event_type', 'order_ID', 'price', 'direction', 'midprice'], inplace=True)
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[numerical_columns] = scaler.fit_transform(features_df[numerical_columns])
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[col] = features_df[col].astype('category')
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# Processed files: AES_2019-01-04_34200000_57600000_orderbook_10.csv AES_2019-01-04_34200000_57600000_message_10.csv
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:260: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df.drop(columns=['event_type', 'order_ID', 'price', 'direction', 'midprice'], inplace=True)
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[numerical_columns] = scaler.fit_transform(features_df[numerical_columns])
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[col] = features_df[col].astype('category')
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# Processed files: AES_2019-01-07_34200000_57600000_orderbook_10.csv AES_2019-01-07_34200000_57600000_message_10.csv
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:260: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df.drop(columns=['event_type', 'order_ID', 'price', 'direction', 'midprice'], inplace=True)
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[numerical_columns] = scaler.fit_transform(features_df[numerical_columns])
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[col] = features_df[col].astype('category')
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# Processed files: AES_2019-01-08_34200000_57600000_orderbook_10.csv AES_2019-01-08_34200000_57600000_message_10.csv
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:260: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df.drop(columns=['event_type', 'order_ID', 'price', 'direction', 'midprice'], inplace=True)
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[numerical_columns] = scaler.fit_transform(features_df[numerical_columns])
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[col] = features_df[col].astype('category')
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# Processed files: AES_2019-01-09_34200000_57600000_orderbook_10.csv AES_2019-01-09_34200000_57600000_message_10.csv
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:260: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df.drop(columns=['event_type', 'order_ID', 'price', 'direction', 'midprice'], inplace=True)
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[numerical_columns] = scaler.fit_transform(features_df[numerical_columns])
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[col] = features_df[col].astype('category')
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# Processed files: AES_2019-01-10_34200000_57600000_orderbook_10.csv AES_2019-01-10_34200000_57600000_message_10.csv
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:260: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df.drop(columns=['event_type', 'order_ID', 'price', 'direction', 'midprice'], inplace=True)
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[numerical_columns] = scaler.fit_transform(features_df[numerical_columns])
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[col] = features_df[col].astype('category')
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# Processed files: AES_2019-12-30_34200000_57600000_orderbook_10.csv AES_2019-12-30_34200000_57600000_message_10.csv
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:260: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df.drop(columns=['event_type', 'order_ID', 'price', 'direction', 'midprice'], inplace=True)
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[numerical_columns] = scaler.fit_transform(features_df[numerical_columns])
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[col] = features_df[col].astype('category')
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# Processed files: AES_2019-12-31_34200000_57600000_orderbook_10.csv AES_2019-12-31_34200000_57600000_message_10.csv
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:260: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df.drop(columns=['event_type', 'order_ID', 'price', 'direction', 'midprice'], inplace=True)
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[numerical_columns] = scaler.fit_transform(features_df[numerical_columns])
# /nfs/home/jingt/dissertation-iceberg/prediction_ML_pipeline.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df[col] = features_df[col].astype('category')
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)
# /nfs/home/jingt/dissertation-iceberg/order_imbalance.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime_bins'] = df.index.get_level_values('datetime').ceil(delta)

# %%
plt.hist(df_dict['1min']['order_imbalance_hid'])
plt.show()

# %%
delta = "1min"

plot_acf(df_dict[delta]['order_imbalance_hid'], lags=range(2, 30))
plt.ylim(-0.1, 0.1)
plt.show()

# %%
plot_pacf(df_dict[delta]['order_imbalance_hid'], lags=range(2, 30))
plt.ylim(-0.1, 0.1)
plt.show()
